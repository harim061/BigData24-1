# %% [markdown]
# # 판다스 연습 퀴즈

# %%
# csv파일 (data.csv) 생성하기
import pandas as pd
import numpy as np
data = {
    "메뉴":['아메리카노','카페라떼','카페모카', '바닐라라떼', '녹차', '초코라떼', '바닐라콜드브루'],
    "가격":[4100, 4600, 4600, 5100, 4100, 5000, 5100],
    "할인율":[0.5, 0.1, 0.2, 0.3, 0, 0, 0],
    "칼로리":[10, 180, 420, 320, 20, 500, 400],
    "원두":['콜롬비아', np.NaN, '과테말라', np.NaN, '한국', '콜롬비아', np.NaN],
    "이벤트가":[1900, 2300, np.NaN, 2600, np.NaN, 3000, 3200],
}
df = pd.DataFrame(data)
df.to_csv('data.csv', index=False)

# %%
# 데이터 불러오기
df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180   NaN  2300.0
# 2     카페모카  4600  0.2  420  과테말라     NaN
# 3    바닐라라떼  5100  0.3  320   NaN  2600.0
# 4       녹차  4100  0.0   20    한국     NaN
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400   NaN  3200.0

# %% [markdown]
# ## 조건필터

# %%
# 문제 [1] 1개 조건, 할인율 > 0.2인 메뉴에 대한 정보를 보기
cond =df['할인율'] > 0.2
df[cond]
# Out:
#       메뉴    가격  할인율  칼로리    원두    이벤트가
# 0  아메리카노  4100  0.5   10  콜롬비아  1900.0
# 3  바닐라라떼  5100  0.3  320   NaN  2600.0

# %%
# 문제 [2] 2개 조건, 할인율 > 0.2 AND 칼로리 < 200인 메뉴에 대한 정보를 보기
cond =( df['할인율'] >0.2) & (df['칼로리'] <200)
df[cond]
# Out:
#       메뉴    가격  할인율  칼로리    원두    이벤트가
# 0  아메리카노  4100  0.5   10  콜롬비아  1900.0

# %%
# 문제 [3] 2개 조건, 할인율 > 0.2 OR 칼로리 < 200인 메뉴에 대한 정보를 보기
cond = (df['할인율']>0.2 )|( df['칼로리']<200)
df[cond]
# Out:
#       메뉴    가격  할인율  칼로리    원두    이벤트가
# 0  아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1   카페라떼  4600  0.1  180   NaN  2300.0
# 3  바닐라라떼  5100  0.3  320   NaN  2600.0
# 4     녹차  4100  0.0   20    한국     NaN

# %%
# 문제 [4] 문자열 1개 조건, 원두 이름이 "콜롬비아"인 메뉴에 대한 정보를 보기
cond = (df['원두']=='콜롬비아')
df[cond]
# Out:
#       메뉴    가격  할인율  칼로리    원두    이벤트가
# 0  아메리카노  4100  0.5   10  콜롬비아  1900.0
# 5   초코라떼  5000  0.0  500  콜롬비아  3000.0

# %%
# 문제 [5] 문자열 조건, 원두 이름이 "콜롬비아" AND 가격 < 4500인 메뉴에 대한 정보를 보기
cond = (df['원두'] == '콜롬비아') & (df['가격']<4500)
df[cond]
# Out:
#       메뉴    가격  할인율  칼로리    원두    이벤트가
# 0  아메리카노  4100  0.5   10  콜롬비아  1900.0

# %% [markdown]
# ## 결측치

# %%
# 문제 [6] 컬럼별 결측치 갯수 확인
df.isnull().sum()
# Out:
# 메뉴      0
# 가격      0
# 할인율     0
# 칼로리     0
# 원두      3
# 이벤트가    2
# dtype: int64

# %%
# 문제 [7] 결측값 채우기, 원두 결측치를 "코스타리카"로 채우기
df['원두'] = df['원두'].fillna('코스타리카')

# %%
# 데이터 확인
df
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라     NaN
# 3    바닐라라떼  5100  0.3  320  코스타리카  2600.0
# 4       녹차  4100  0.0   20     한국     NaN
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
# 문제 [8] 결측값 채우기, '이벤트가'컬럼 결측치는 1900으로 결측치 채움
df['이벤트가'] = df['이벤트가'].fillna(1900)

# %% [markdown]
# ## 값 변경

# %%
# 데이터 확인
df
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라  1900.0
# 3    바닐라라떼  5100  0.3  320  코스타리카  2600.0
# 4       녹차  4100  0.0   20     한국  1900.0
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
# 문제 [9] 데이터 값 변경하기 : 아메리카노 -> 룽고, 녹차 -> 그린티, replace 문 사용해보기
df = df.replace('아메리카노','룽고')
df = df.replace('녹차','그린티')

# %%
# 데이터 확인
df
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0       룽고  4100  0.5   10   콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라  1900.0
# 3    바닐라라떼  5100  0.3  320  코스타리카  2600.0
# 4      그린티  4100  0.0   20     한국  1900.0
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
# 문제 [10] 이벤트가격 1900 -> 1500 변경하기, replace 사용
df = df.replace(1900,1500)
df
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0       룽고  4100  0.5   10   콜롬비아  1500.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라  1500.0
# 3    바닐라라떼  5100  0.3  320  코스타리카  2600.0
# 4      그린티  4100  0.0   20     한국  1500.0
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
# 문제 [11] 메뉴 "바닐라라떼"의 원두를 "과테말라"로 변경, df.loc 사용

df.loc[df['메뉴'] == '바닐라라떼', '원두'] = '과테말라'

# %%
df
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0       룽고  4100  0.5   10   콜롬비아  1500.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라  1500.0
# 3    바닐라라떼  5100  0.3  320   과테말라  2600.0
# 4      그린티  4100  0.0   20     한국  1500.0
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
# 문제 [12] 이벤트가 전체를 1000으로 변경
df['이벤트가'] =1000

# %% [markdown]
# ## 내장함수
# - 데이터 핸들링을 위한 판다스 기초1(EDA) 부분에서 일부 내장함수를 학습했고, 그외 함수에 대해 살펴봄

# %%
# 데이터 불러오기
import pandas as pd
import numpy as np
data = {
    "메뉴":['아메리카노','카페라떼','카페모카', '바닐라라떼', '녹차', '초코라떼', '바닐라콜드브루'],
    "가격":[4100, 4600, 4600, 5100, 4100, 5000, 5100],
    "할인율":[0.5, 0.1, 0.2, 0.3, 0, 0, 0],
    "칼로리":[10, 180, 420, 320, 20, 500, 400],
    "원두":['콜롬비아', np.NaN, '과테말라', np.NaN, '한국', '콜롬비아', np.NaN],
    "이벤트가":[1900, 2300, np.NaN, 2600, np.NaN, 3000, 3200],
}
df = pd.DataFrame(data)
df.to_csv('data.csv', index=False)
df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180   NaN  2300.0
# 2     카페모카  4600  0.2  420  과테말라     NaN
# 3    바닐라라떼  5100  0.3  320   NaN  2600.0
# 4       녹차  4100  0.0   20    한국     NaN
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400   NaN  3200.0

# %%
# 문제 [13] 컬럼별 데이터 갯수 카운트, NULL 값은 제외됨, count() 사용, 기본값 axis=0
df.count(axis=0)
# Out:
# 메뉴      7
# 가격      7
# 할인율     7
# 칼로리     7
# 원두      4
# 이벤트가    5
# dtype: int64

# %%
# 행별 데이터 갯수 카운트, NULL 값은 제외됨, count() 사용, axis=1
df.count(axis=1)
# Out:
# 0    6
# 1    5
# 2    5
# 3    5
# 4    5
# 5    6
# 6    5
# dtype: int64

# %%
# 문제 [14] 데이터 갯수 len() 함수 사용, shape 사용
df.shape[0]
# Out:
# 7

# %%
# 가격 컬럼의 최대값 구하기
df.가격.max()
df.max()
# Out:
# <ipython-input-121-6c797170dc4a>:3: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# 메뉴        카페모카
# 가격        5100
# 할인율        0.5
# 칼로리        500
# 이벤트가    3200.0
# dtype: object

# %%
# 문제 [15] 가격 컬럼의 최소값 구하기
df.가격.min()
df.min()
# Out:
# <ipython-input-122-e3681ef358bd>:3: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# 메뉴          녹차
# 가격        4100
# 할인율        0.0
# 칼로리         10
# 이벤트가    1900.0
# dtype: object

# %%
# 가격 컬럼의 평균값 구하기
df.가격.mean()
df.mean()
# Out:
# <ipython-input-123-7aadbee1a8af>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# 가격      4657.142857
# 할인율        0.157143
# 칼로리      264.285714
# 이벤트가    2600.000000
# dtype: float64

# %%
# 문제 [16] 가격 컬럼의 중앙값 구하기
df.가격.median()
df.median()
# Out:
# <ipython-input-124-441cf562a19d>:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# 가격      4600.0
# 할인율        0.1
# 칼로리      320.0
# 이벤트가    2600.0
# dtype: float64

# %%
# 합계
df.가격.sum()
df.sum()
# Out:
# <ipython-input-125-ada7729bbb78>:3: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.sum()
# 메뉴      아메리카노카페라떼카페모카바닐라라떼녹차초코라떼바닐라콜드브루
# 가격                                32600
# 할인율                                 1.1
# 칼로리                                1850
# 이벤트가                            13000.0
# dtype: object

# %%
# 문제 [17] 가격 컬럼의 표준편차 구하기
df.가격.std()
df.std()
# Out:
# <ipython-input-126-05f74078a8c5>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# 가격      435.343324
# 할인율       0.190238
# 칼로리     196.965068
# 이벤트가    524.404424
# dtype: float64

# %%
# 분산
df.가격.var()
df.var()
# Out:
# <ipython-input-127-d3da5f364ed9>:3: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# 가격      189523.809524
# 할인율          0.036190
# 칼로리      38795.238095
# 이벤트가    275000.000000
# dtype: float64

# %%
# 백분위수 알아보기
df['가격'].describe()
# Out:
# count       7.000000
# mean     4657.142857
# std       435.343324
# min      4100.000000
# 25%      4350.000000
# 50%      4600.000000
# 75%      5050.000000
# max      5100.000000
# Name: 가격, dtype: float64

# %%
# 가격 컬럼의 하위 25% 값 구하기, quantile() 함수 사용
df.가격.quantile(.25)
# Out:
# 4350.0

# %%
# 문제 [18] 가격 컬럼의 상위 25% 값 구하기, quantile() 함수 사용
df.가격.quantile(.75)
# Out:
# 5050.0

# %%
# 가격 컬럼의 하위 25% 데이터 모두 보기
cond=(df.가격 <= df.가격.quantile(.25))
df[cond]
# Out:
#       메뉴    가격  할인율  칼로리    원두    이벤트가
# 0  아메리카노  4100  0.5   10  콜롬비아  1900.0
# 4     녹차  4100  0.0   20    한국     NaN

# %%
# 가격 컬럼의 상위 25% 데이터 모두 보기
cond=(df.가격 >= df.가격.quantile(.75))
df[cond]
# Out:
#         메뉴    가격  할인율  칼로리   원두    이벤트가
# 3    바닐라라떼  5100  0.3  320  NaN  2600.0
# 6  바닐라콜드브루  5100  0.0  400  NaN  3200.0

# %%
# 문제 [19] 최빈값 구하기, mode(), 주의 : 결과는 Series이다.
cond = df['가격'].mode()
cond
# Out:
# 0    4100
# 1    4600
# 2    5100
# Name: 가격, dtype: int64

# %% [markdown]
# **심화학습(apply함수)**

# %%
# 데이터 확인
df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180   NaN  2300.0
# 2     카페모카  4600  0.2  420  과테말라     NaN
# 3    바닐라라떼  5100  0.3  320   NaN  2600.0
# 4       녹차  4100  0.0   20    한국     NaN
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400   NaN  3200.0

# %%
# apply 함수 예시
def cal(x):
  if x>=300:
    return 'No'
  else:
    return 'Yes'
df['칼로리'].apply(cal)
# Out:
# 0    Yes
# 1    Yes
# 2     No
# 3     No
# 4    Yes
# 5     No
# 6     No
# Name: 칼로리, dtype: object

# %%
# apply 적용해서 새로운 컬럼 생성 (칼로리 컬럼 활용)
df['먹어도될까요']=df['칼로리'].apply(cal)

# %% [markdown]
# ## 그룹핑

# %%
# 문제 [20] 원두별 가격 평균 구하기
df.groupby(['원두']).mean()
# Out:
# <ipython-input-137-2e89bde7e420>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['원두']).mean()
#           가격   할인율    칼로리    이벤트가
# 원두
# 과테말라  4600.0  0.20  420.0     NaN
# 콜롬비아  4550.0  0.25  255.0  2450.0
# 한국    4100.0  0.00   20.0     NaN

# %%
# (원두와 할인율)별 평균값 구하기
df.groupby(['원두', '할인율']).mean()
# Out:
# <ipython-input-138-ce06474264ff>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['원두', '할인율']).mean()
#               가격    칼로리    이벤트가
# 원두   할인율
# 과테말라 0.2  4600.0  420.0     NaN
# 콜롬비아 0.0  5000.0  500.0  3000.0
#      0.5  4100.0   10.0  1900.0
# 한국   0.0  4100.0   20.0     NaN

# %%
# 문제 [21] (원두와 할인율)별 가격 평균값 구하기
df.groupby(['원두','할인율'])['가격'].mean()
# Out:
# 원두    할인율
# 과테말라  0.2    4600.0
# 콜롬비아  0.0    5000.0
#       0.5    4100.0
# 한국    0.0    4100.0
# Name: 가격, dtype: float64

# %%
# group1에서 ['콜롬비아'  0.0]의 가격
group1.index
group1.loc[('콜롬비아', 0.0)]

# %%
# 1개 인덱스 형태로 리셋
group2=df.groupby(['원두', '할인율'])['가격'].mean().reset_index()

# %%
group2
# Out:
#      원두  할인율      가격
# 0  과테말라  0.2  4600.0
# 1  콜롬비아  0.0  5000.0
# 2  콜롬비아  0.5  4100.0
# 3    한국  0.0  4100.0

# %%
# 문제 [22] group2에서 원두='콜롬비아' AND 할인율=0.0 의 가격
cond = (group2['원두'] =='콜롬비아' ) & (group2['할인율']==0.0)
group2[cond]['가격']
# Out:
# 1    5000.0
# Name: 가격, dtype: float64

# %%
# csv파일 (data.csv) 생성
import pandas as pd
import numpy as np
data = {
    "메뉴":['아메리카노','카페라떼','카페모카', '바닐라라떼', '녹차', '초코라떼', '바닐라콜드브루'],
    "가격":[4100, 4600, 4600, 5100, 4100, 5000, 5100],
    "할인율":[0.5, 0.1, 0.2, 0.3, 0, 0, 0],
    "칼로리":[10, 180, 420, 320, 20, 500, 400],
    "원두":['콜롬비아', np.NaN, '과테말라', np.NaN, '한국', '콜롬비아', np.NaN],
    "이벤트가":[1900, 2300, np.NaN, 2600, np.NaN, 3000, 3200],
}
data = pd.DataFrame(data)
data.to_csv('data.csv', index=False)

# %%
# 데이터 불러오기
df = pd.read_csv('data.csv')
df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180   NaN  2300.0
# 2     카페모카  4600  0.2  420  과테말라     NaN
# 3    바닐라라떼  5100  0.3  320   NaN  2600.0
# 4       녹차  4100  0.0   20    한국     NaN
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400   NaN  3200.0

# %%
# 문제 [23] 결측치 채우기 : '이벤트가' 컬럼 결측치는 이벤트가격 데이터 중 최소값으로 결측치 채움
df['이벤트가'] = df['이벤트가'].fillna(df['이벤트가'].min())
df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180   NaN  2300.0
# 2     카페모카  4600  0.2  420  과테말라  1900.0
# 3    바닐라라떼  5100  0.3  320   NaN  2600.0
# 4       녹차  4100  0.0   20    한국  1900.0
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400   NaN  3200.0

# %% [markdown]
# **2. '원두' 컬럼 결측치는 원두 데이터 중 최빈값으로 결측치 채움**

# %%
# 문제 [24] 결측치 채우기 :'원두' 컬럼 결측치는 원두 데이터 중 최빈값으로 결측치 채움


most = df['원두'].mode()

df['원두'] = df['원두'].fillna(most[0])

df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180  콜롬비아  2300.0
# 2     카페모카  4600  0.2  420  과테말라  1900.0
# 3    바닐라라떼  5100  0.3  320  콜롬비아  2600.0
# 4       녹차  4100  0.0   20    한국  1900.0
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  콜롬비아  3200.0

# %% [markdown]
# **3. 가격이 5000 이상인 데이터의 수를 구하시오**

# %%
# 문제 [25] 가격이 5000 이상인 데이터의 개수를 구하시오
cond = df['가격'] >= 5000
df[cond].shape[0]
# Out:
# 3
